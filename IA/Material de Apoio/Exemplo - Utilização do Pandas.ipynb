# %%
import pandas as pd

# %%
# Carrega o Dataset WorldHappinessDataset.csv.
DataFrame = pd.read_csv("Database/WorldHappinessDataset.csv")

# Exibe as 5 primeiras amostras do DataFrame
DataFrame.head()
# Out:
#         Country  Year  Index   Rank
# 0   Afghanistan  2013  4.040  143.0
# 1     Singapore  2013  6.546   30.0
# 2       Comoros  2013  3.851  149.0
# 3  Sierra Leone  2013  4.318  127.0
# 4         Congo  2013    NaN    NaN

# %%
# Exibe as 20 primeiras amostras do DataFrame
DataFrame.head(20)
# Out:
#               Country  Year  Index   Rank
# 0         Afghanistan  2013  4.040  143.0
# 1           Singapore  2013  6.546   30.0
# 2             Comoros  2013  3.851  149.0
# 3        Sierra Leone  2013  4.318  127.0
# 4               Congo  2013    NaN    NaN
# 5              Serbia  2013  4.813  106.0
# 6   Congo Brazzaville  2013  4.297  129.0
# 7             Senegal  2013  3.959  147.0
# 8      Congo Kinshasa  2013  4.578  117.0
# 9        Saudi Arabia  2013  6.480   33.0
# 10             Rwanda  2013  3.715  152.0
# 11         Costa Rica  2013  7.257   12.0
# 12             Russia  2013  5.464   68.0
# 13            Croatia  2013  5.661   58.0
# 14            Romania  2013  5.033   90.0
# 15           Colombia  2013  6.416   35.0
# 16             Cyprus  2013  6.466   34.0
# 17            Czechia  2013  6.290   39.0
# 18        Puerto Rico  2013    NaN    NaN
# 19            Denmark  2013  7.693    1.0

# %%
# Exibe as 5 últimas amostras do DataFrame
DataFrame.tail()
# Out:
#                 Country  Year  Index   Rank
# 1665  Congo Brazzaville  2023  5.267   86.0
# 1666             Rwanda  2023    NaN    NaN
# 1667     Congo Kinshasa  2023  3.207  133.0
# 1668            Comoros  2023  3.545  130.0
# 1669           Zimbabwe  2023  3.204  134.0

# %%
# Exibe as 20 últimas amostras do DataFrame
DataFrame.tail(20)
# Out:
#                 Country  Year  Index   Rank
# 1650        Philippines  2023  5.523   76.0
# 1651              Egypt  2023  4.170  121.0
# 1652         Costa Rica  2023  6.609   23.0
# 1653             Russia  2023  5.661   70.0
# 1654              Chile  2023  6.334   35.0
# 1655           Slovakia  2023  6.469   29.0
# 1656              China  2023  5.818   64.0
# 1657          Singapore  2023  6.587   25.0
# 1658       Sierra Leone  2023  3.138  135.0
# 1659           Colombia  2023  5.630   72.0
# 1660            Romania  2023  5.689   24.0
# 1661             Serbia  2023  6.144   45.0
# 1662            Senegal  2023  4.855  102.0
# 1663              Congo  2023    NaN    NaN
# 1664       Saudi Arabia  2023  6.463   30.0
# 1665  Congo Brazzaville  2023  5.267   86.0
# 1666             Rwanda  2023    NaN    NaN
# 1667     Congo Kinshasa  2023  3.207  133.0
# 1668            Comoros  2023  3.545  130.0
# 1669           Zimbabwe  2023  3.204  134.0

# %%
Country = DataFrame.Country

Country.head(10)
# Out:
# 0          Afghanistan
# 1            Singapore
# 2              Comoros
# 3         Sierra Leone
# 4                Congo
# 5               Serbia
# 6    Congo Brazzaville
# 7              Senegal
# 8       Congo Kinshasa
# 9         Saudi Arabia
# Name: Country, dtype: object

# %%
Country_Dicionario = DataFrame["Country"]

Country_Dicionario.head(10)
# Out:
# 0          Afghanistan
# 1            Singapore
# 2              Comoros
# 3         Sierra Leone
# 4                Congo
# 5               Serbia
# 6    Congo Brazzaville
# 7              Senegal
# 8       Congo Kinshasa
# 9         Saudi Arabia
# Name: Country, dtype: object

# %%
print(DataFrame["Country"].value_counts())
# Out:
# Afghanistan                 10
# Norway                      10
# North Macedonia             10
# Finland                     10
# North Cyprus                10
#                             ..
# Central African Republic    10
# Palestine                   10
# South Korea                 10
# South Sudan                 10
# Armenia                     10
# Name: Country, Length: 167, dtype: int64

# %%
pd.set_option("display.max_rows", None) # sem maximo de linhas

# %%
print(DataFrame["Country"].value_counts())
# Out:
# Afghanistan                 10
# Norway                      10
# North Macedonia             10
# Finland                     10
# North Cyprus                10
# France                      10
# Nigeria                     10
# Niger                       10
# Gabon                       10
# Nicaragua                   10
# Gambia                      10
# New Zealand                 10
# Georgia                     10
# Netherlands                 10
# Germany                     10
# Nepal                       10
# Mexico                      10
# Moldova                     10
# Honduras                    10
# Ethiopia                    10
# Eswatini                    10
# Haiti                       10
# Hong Kong                   10
# Libya                       10
# Liberia                     10
# Ivory Coast                 10
# Lesotho                     10
# Jamaica                     10
# Lebanon                     10
# Japan                       10
# ...

# %%
Linhas = DataFrame[100:105]

Linhas.head(10)
# Out:
#        Country  Year  Index   Rank
# 100      Italy  2013  6.021   45.0
# 101    Hungary  2013  4.775  110.0
# 102  Mauritius  2013  5.477   67.0
# 103  Hong Kong  2013  5.523   64.0
# 104   Eswatini  2013    NaN    NaN

# %%
DataFrame.at[0,"Country"] = "Brasil"

DataFrame.head()
# Out:
#         Country  Year  Index   Rank
# 0        Brasil  2013  4.040  143.0
# 1     Singapore  2013  6.546   30.0
# 2       Comoros  2013  3.851  149.0
# 3  Sierra Leone  2013  4.318  127.0
# 4         Congo  2013    NaN    NaN

# %%
print(len(DataFrame))
# Out:
# 1670

# %%
X = []

for i in range(0, len(DataFrame)):
    Index = DataFrame.at[i,"Index"]
    Rank = DataFrame.at[i, "Rank"]
    
    X.append([Index, Rank])

print("Tamanho: ", len(X))

for i in range(0, 20):
    print(i, ":", X[i])
# Out:
# Tamanho:  1670
# 0 : [4.04, 143.0]
# 1 : [6.546, 30.0]
# 2 : [3.851, 149.0]
# 3 : [4.318, 127.0]
# 4 : [nan, nan]
# 5 : [4.813, 106.0]
# 6 : [4.297, 129.0]
# 7 : [3.959, 147.0]
# 8 : [4.578, 117.0]
# 9 : [6.48, 33.0]
# 10 : [3.715, 152.0]
# 11 : [7.257, 12.0]
# 12 : [5.464, 68.0]
# 13 : [5.661, 58.0]
# 14 : [5.033, 90.0]
# 15 : [6.416, 35.0]
# 16 : [6.466, 34.0]
# 17 : [6.29, 39.0]
# 18 : [nan, nan]
# 19 : [7.693, 1.0]
